# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\Internal Attachment\Data Visualization\cleaned_sbt_japan.csv")
df.head()
# Out:
#     car_brand car_model  mileage_km  engine_size_cc            transmission  \
# 0        AUDI  TT COUPE     56000.0          2000.0  Automatic Transmission
# 1  VOLKSWAGEN      GOLF     48000.0          1200.0  Automatic Transmission
# 2         KIA    MOHAVE     37000.0          2959.0  Automatic Transmission
# 3         BMW        i3     51000.0           900.0  Automatic Transmission
# 4     GENESIS       G80    120000.0          2497.0  Automatic Transmission
#
#   fuel_type steering_type drive_train no_of_seats no_of_doors  ...  \
# 0    Petrol           RHD         4WD     4 Seats     3 Doors  ...
# 1    Petrol           RHD       Other     5 Seats     5 Doors  ...
# 2    Diesel           LHD         4WD     7 Seats     4 Doors  ...
# 3    Hybrid           RHD       Other     4 Seats     5 Doors  ...
# 4    Petrol           LHD         4WD     5 Seats     4 Doors  ...
#
#   Power Steering  Air Conditioner  Navigation  Air Bag  \
# 0              1                1           0        1
# 1              1                1           0        1
# 2              1                1           0        1
# 3              1                1           0        1
# 4              1                1           0        1
#
#    Anti-Lock Brake System  Fog Lights  Power Windows  Alloy Wheels  year  \
# 0                       0           0              1             1  2015
# 1                       0           0              1             1  2018
# 2                       0           0              1             1  2022
# 3                       0           0              1             1  2016
# 4                       0           0              1             1  2020
#
#    price(Ksh)
# 0   3407249.0
# 1   2390153.0
# 2   6545952.0
# 3   2360003.0
# 4   5564201.0
#
# [5 rows x 21 columns]

# %%
list(df.columns)
# Out:
# ['car_brand',
#  'car_model',
#  'mileage_km',
#  'engine_size_cc',
#  'transmission',
#  'fuel_type',
#  'steering_type',
#  'drive_train',
#  'no_of_seats',
#  'no_of_doors',
#  'body_type',
#  'Power Steering',
#  'Air Conditioner',
#  'Navigation',
#  'Air Bag',
#  'Anti-Lock Brake System',
#  'Fog Lights',
#  'Power Windows',
#  'Alloy Wheels',
#  'year',
#  'price(Ksh)']

# %% [markdown]
# #### What is the average price of each manufacturer

# %%
average_prices = df.groupby('car_brand')['price(Ksh)'].mean()
average_prices.round(2)
# Out:
# car_brand
# ALFA            5809306.64
# AMG             8260609.94
# AUDI            5937714.57
# Abarth          3713165.07
# Aston          12131615.79
# BMW             7065283.98
# BYD             5804562.00
# Bentley        11719027.49
# Buick           4753584.00
# CADILLAC        7429580.00
# CHERY           1849833.00
# CHEVROLET       8481098.05
# CHRYSLER        6451347.93
# CITROEN         3544252.55
# DAIHATSU        2387523.84
# DODGE           7612084.31
# FAW            12155849.00
# FERRARI        12155849.00
# FIAT            3017574.44
# FORD            5667070.83
# GELLY           1707538.00
# GENESIS         6648423.16
# HONDA           3339613.20
# HYUNDAI         5070702.77
# INFINITI        8329335.00
# ISUZU           6118440.30
# JAGUAR          7706342.90
# JEEP            6711750.53
# KIA             5464083.98
# LAND            7849586.78
# LEADING         8596999.25
# LEXUS           7072870.93
# Lamborghini    12155849.00
# Lotus           9892204.55
# MASERATI        8670467.10
# MAZDA           2796851.99
# MERCEDES        6726277.74
# MG              3758827.00
# MINI            3562861.76
# MITSUBISHI      5304097.85
# MITSUOKA        6606178.40
# NIO             7287762.00
# NISSAN          3966542.36
# PEUGEOT         4099557.36
# PORSCHE         8616685.03
# ROLLS          12155849.00
# Renault         4143176.65
# SUBARU          3637708.44
# SUZUKI          2703815.97
# TESLA           8171055.50
# TOYOTA          4561920.85
# VOLKSWAGEN      3494761.51
# VOLVO           6554031.62
# XPENG           6129430.00
# Name: price(Ksh), dtype: float64

# %% [markdown]
# #### Does the transmission affect car price

# %%
transmission_prices = df.groupby('transmission')['price(Ksh)'].mean()

plt.figure(figsize = (8, 6))
plt.bar(transmission_prices.index,transmission_prices.values,color = ['skyblue', 'salmon'])
plt.xlabel('Transmission Type')
plt.ylabel('Average Price (Ksh)')
plt.title('Average car prices by transmission type')
plt.grid(axis = 'y',linestyle = '--', alpha = 0.7)
plt.show()

# %% [markdown]
# #### Effects of mileage on car prices

# %%
mileage = df.groupby('mileage_km')['price(Ksh)'].mean()
plt.figure(figsize = (8,6))
plt.scatter(mileage.index, mileage.values, marker = 'o', color = 'b' )
plt.xlabel('Mileage (miles)')
plt.ylabel('Price ($)')
plt.title('Effect of Mileage on Car Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Correlation Matrix

# %%
import seaborn as sns

# %%
corr_matrix = df.corr()

plt.figure(figsize = (6,4))
sns.heatmap(corr_matrix, annot = True, cmap = 'coolwarm', vmin = -1, vmax = 1)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\AMON TOT\AppData\Local\Temp\ipykernel_1704\2545831958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
