# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cleaned_sbt_japan.csv')
df.head(5)
# Out:
#     car_brand car_model  mileage_km  engine_size_cc            transmission  \
# 0        AUDI  TT COUPE     56000.0          2000.0  Automatic Transmission
# 1  VOLKSWAGEN      GOLF     48000.0          1200.0  Automatic Transmission
# 2         KIA    MOHAVE     37000.0          2959.0  Automatic Transmission
# 3         BMW        i3     51000.0           900.0  Automatic Transmission
# 4     GENESIS       G80    120000.0          2497.0  Automatic Transmission
#
#   fuel_type steering_type drive_train no_of_seats no_of_doors  ...  \
# 0    Petrol           RHD         4WD     4 Seats     3 Doors  ...
# 1    Petrol           RHD       Other     5 Seats     5 Doors  ...
# 2    Diesel           LHD         4WD     7 Seats     4 Doors  ...
# 3    Hybrid           RHD       Other     4 Seats     5 Doors  ...
# 4    Petrol           LHD         4WD     5 Seats     4 Doors  ...
#
#   Power Steering  Air Conditioner  Navigation  Air Bag  \
# ...

# %%
#What are the top 10 manufacturers with the most cars.
unique_manufacturers = df['car_brand'].unique()
print(unique_manufacturers)
# Out:
# ['AUDI' 'VOLKSWAGEN' 'KIA' 'BMW' 'GENESIS' 'NISSAN' 'MERCEDES' 'LEXUS'
#  'LAND' 'HONDA' 'TOYOTA' 'FORD' 'SUBARU' 'MAZDA' 'HYUNDAI' 'MASERATI'
#  'CHRYSLER' 'CITROEN' 'SUZUKI' 'ALFA' 'AMG' 'MITSUBISHI' 'FERRARI'
#  'Abarth' 'ROLLS' 'CHEVROLET' 'MINI' 'VOLVO' 'PEUGEOT' 'Renault' 'JEEP'
#  'DAIHATSU' 'FIAT' 'TESLA' 'PORSCHE' 'CADILLAC' 'Bentley' 'JAGUAR'
#  'Lamborghini' 'BYD' 'ISUZU' 'MITSUOKA' 'Lotus' 'INFINITI' 'LEADING'
#  'Aston' 'Buick' 'DODGE' 'XPENG' 'MG' 'FAW' 'NIO' 'CHERY' 'GELLY']

# %%
#gives us the number of cars each brand has manufactured
count_manufacturers = df['car_brand'].value_counts()
print(count_manufacturers)
# Out:
# car_brand
# TOYOTA         5851
# MERCEDES       3462
# BMW            3196
# GENESIS        1882
# KIA            1554
# HYUNDAI        1458
# NISSAN         1351
# AUDI           1169
# LAND            935
# HONDA           747
# MAZDA           601
# LEXUS           587
# SUBARU          551
# SUZUKI          525
# PORSCHE         408
# FORD            403
# MASERATI        294
# VOLKSWAGEN      272
# Abarth          267
# FIAT            235
# PEUGEOT         223
# JEEP            216
# VOLVO           183
# MITSUBISHI      182
# ALFA            175
# Renault         156
# MINI            142
# DAIHATSU         97
# CHRYSLER         92
# CITROEN          91
# JAGUAR           90
# CHEVROLET        85
# Lamborghini      80
# CADILLAC         75
# Bentley          71
# AMG              53
# ISUZU            47
# Aston            43
# FERRARI          38
# Lotus            33
# ROLLS            18
# DODGE            16
# MITSUOKA         15
# INFINITI          8
# ...

# %%
#gives us the max value within the car brand column
max_manufacturers = df['car_brand'].value_counts().max()
print(max_manufacturers)
# Out:
# 5851

# %%
#gives us the top 10 manufacturers.
top_manufacturers = df['car_brand'].value_counts().nlargest(10)
print(top_manufacturers)
# Out:
# car_brand
# TOYOTA      5851
# MERCEDES    3462
# BMW         3196
# GENESIS     1882
# KIA         1554
# HYUNDAI     1458
# NISSAN      1351
# AUDI        1169
# LAND         935
# HONDA        747
# Name: count, dtype: int64

# %%
#begin of visualization using a std fig size of (10,6)
plt.figure(figsize=(10,6))
sns.barplot(x=top_manufacturers.index, y=top_manufacturers.values, palette='viridis')
plt.title('TOP 10 CAR MANUFACTURERS IN JAPAN')
plt.xlabel('Car brands')
plt.ylabel('No. of cars manufactured')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#graph showing top 5 toyota models
top_toyota_models=df[df["car_brand"]== "TOYOTA"]["car_model"].value_counts().nlargest(5)
print(top_toyota_models)
# Out:
# car_model
# PRIUS                 1112
# LAND CRUISER PRADO     418
# CROWN HYBRID           279
# 86                     273
# PRIUS S                239
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_toyota_models.index, y=top_toyota_models.values, palette='mako')
plt.title('Top 5 TOYOTA Models')
plt.xlabel('Car Model')
plt.ylabel('No. of cars manufactured')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#No of cars by year
plt.figure(figsize=(10,6))
sns.countplot(x="year", data=df, palette="rocket")
plt.title("CAR PRODUCTION IN RECENT YEARS")
plt.xlabel("Years")
plt.ylabel("No. of cars manufactured")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#mileage effect on vehicles
list(df.columns)
# Out:
# ['car_brand',
#  'car_model',
#  'mileage_km',
#  'engine_size_cc',
#  'transmission',
#  'fuel_type',
#  'steering_type',
#  'drive_train',
#  'no_of_seats',
#  'no_of_doors',
#  'body_type',
#  'Power Steering',
#  'Air Conditioner',
#  'Navigation',
#  'Air Bag',
#  'Anti-Lock Brake System',
#  'Fog Lights',
#  'Power Windows',
#  'Alloy Wheels',
#  'year',
#  'price(Ksh)']

# %%
mileage=df['mileage_km']
main_mileage_by_year=df.groupby('year')['mileage_km'].mean()
print(main_mileage_by_year)
# Out:
# year
# 2015    79619.482496
# 2016    65169.039146
# 2017    62285.649203
# 2018    57834.853420
# 2019    52850.422535
# 2020    43997.678737
# 2021    28504.137360
# 2022    13826.579836
# 2023     4541.839557
# 2024     3200.000000
# Name: mileage_km, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.plot(main_mileage_by_year.index,main_mileage_by_year.values,marker='o',linestyle='-')
plt.title('MILEAGE PER YEAR')
plt.xlabel('Year')
plt.ylabel('Mileage per KM')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#what is the most common fuel type?
fuel=df['fuel_type'].value_counts()
fuel
# Out:
# fuel_type
# Petrol            16556
# Hybrid             6041
# Diesel             5082
# Electric/Other      321
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('AVAILABLE FUEL TYPES')
plt.xlabel('fuel type')
plt.ylabel('No. of cars')
sns.barplot(x=fuel.index,y=fuel.values,palette='rocket')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
drive=df['drive_train'].value_counts(normalize=True)*100
drive
# Out:
# drive_train
# 4WD      47.446429
# Other    32.303571
# 2WD      20.250000
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.title('WHEEL DRIVE COMPARISON')
plt.xlabel('drive type')
plt.ylabel('% of cars')
sns.barplot(x=drive.index,y=drive.values,palette='mako')
# Out:
# <Axes: title={'center': 'WHEEL DRIVE COMPARISON'}, xlabel='drive_train', ylabel='% of cars'>

# %%
plt.figure(figsize=(6,6))
plt.title('AVAILABLE FUEL TYPES')
colours=sns.color_palette('pastel')[0:5]
plt.pie(drive,labels=drive.index,colors=colours)
plt.show()

# %%
#Calculating mean price per engine size
mn=df.groupby('engine_size_cc')['price(Ksh)'].mean()
mn
# Out:
# engine_size_cc
# 900.0     4.793218e+06
# 990.0     1.256130e+06
# 998.0     2.564930e+06
# 1000.0    3.145893e+06
# 1190.0    1.060504e+06
#               ...
# 3999.0    8.853194e+06
# 4000.0    1.054923e+07
# 4134.0    4.739199e+06
# 4200.0    9.092945e+06
# 4300.0    8.544783e+06
# Name: price(Ksh), Length: 153, dtype: float64

# %%
plt.figure(figsize=(15,12))
plt.plot(mn.index,mn.values,marker='o',linestyle='-')
plt.xticks(rotation=90)
plt.title('ENGINE SIZE WITH CORRESPONDING PRICES')
plt.xlabel('Engine size-cc')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
list(df.columns)
# Out:
# ['car_brand',
#  'car_model',
#  'mileage_km',
#  'engine_size_cc',
#  'transmission',
#  'fuel_type',
#  'steering_type',
#  'drive_train',
#  'no_of_seats',
#  'no_of_doors',
#  'body_type',
#  'Power Steering',
#  'Air Conditioner',
#  'Navigation',
#  'Air Bag',
#  'Anti-Lock Brake System',
#  'Fog Lights',
#  'Power Windows',
#  'Alloy Wheels',
#  'year',
#  'price(Ksh)']

# %%
#What's the average price for each manufacture
meanprice=df.groupby('car_brand')['price(Ksh)'].mean()
meanprice.head(5)
# Out:
# car_brand
# ALFA      5.809307e+06
# AMG       8.260610e+06
# AUDI      5.937715e+06
# Abarth    3.713165e+06
# Aston     1.213162e+07
# Name: price(Ksh), dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.title('AVERAGE PRICE FOR EACH MANUFACTURE')
plt.xlabel('Car brand')
plt.ylabel('Mean Price in Ksh (e^-6)')
sns.barplot(x=meanprice.index,y=meanprice.values,palette='rocket')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#does transmission affect car price
data=df.groupby('transmission')['price(Ksh)'].mean()
data
# Out:
# transmission
# Automatic Transmission    5.702664e+06
# Manual Transmission       4.489336e+06
# Name: price(Ksh), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.title('TRANSMISSION')
colours=sns.color_palette('pastel')[0:5]
plt.pie(data,labels=data.index,colors=colours)
plt.show()

# %%
#effect of mileage on price
mileage = df.groupby('mileage_km')['price(Ksh)'].mean()
plt.figure(figsize = (8,6))
plt.scatter(mileage.index, mileage.values, marker = 'o', color = 'b' )
plt.xlabel('Mileage (miles)')
plt.ylabel('Price ($)')
plt.title('Effect of Mileage on Car Prices')
plt.grid(True)
plt.show()

# %%
import numpy as np
# Select only numeric columns for correlation calculation
numeric_columns = df.select_dtypes(include=[np.number])
# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
